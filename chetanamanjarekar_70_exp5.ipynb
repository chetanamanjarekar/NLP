# %% [markdown]
# ## Parts of Speech

# %% [markdown]
# Experiment 05 ~ NLP DLOC ~ Chetana Manjarekar ~ Dept. of CS & DS ~ VCET

# %%
text = "TON 618 (short for Tonantzintla 618) is a hyperluminous, broad-absorption-line, radio-loud quasar and Lyman-alpha blob located near the border of the constellations Canes Venatici and Coma Berenices, with the projected comoving distance of approximately 18.2 billion light-years from Earth."

# %% [markdown]
# ### Importing necessary dependencies

# %%
import nltk
from nltk.tokenize import word_tokenize

# %% [markdown]
# ### Word Tokenization

# %%
words = word_tokenize(text)

# %% [markdown]
# ### Parts of Speech Tagging

# %%
tagged_words = nltk.pos_tag(words, tagset = 'universal')

# %%
tagged_words
# Out:
# [('TON', '.'),
#  ('618', 'NUM'),
#  ('(', '.'),
#  ('short', 'ADJ'),
#  ('for', 'ADP'),
#  ('Tonantzintla', 'NOUN'),
#  ('618', 'NUM'),
#  (')', '.'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('hyperluminous', 'ADJ'),
#  (',', '.'),
#  ('broad-absorption-line', 'ADJ'),
#  (',', '.'),
#  ('radio-loud', 'ADJ'),
#  ('quasar', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Lyman-alpha', 'NOUN'),
#  ('blob', 'NOUN'),
#  ('located', 'VERB'),
#  ('near', 'ADP'),
#  ('the', 'DET'),
#  ('border', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('constellations', 'NOUN'),
#  ('Canes', 'NOUN'),
#  ('Venatici', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Coma', 'NOUN'),
#  ('Berenices', 'NOUN'),
#  (',', '.'),
#  ('with', 'ADP'),
#  ('the', 'DET'),
#  ('projected', 'VERB'),
#  ('comoving', 'NOUN'),
#  ('distance', 'NOUN'),
#  ('of', 'ADP'),
#  ('approximately', 'ADV'),
#  ('18.2', 'NUM'),
#  ('billion', 'NUM'),
#  ('light-years', 'NOUN'),
#  ('from', 'ADP'),
#  ('Earth', 'NOUN'),
#  ('.', '.')]

# %%
for t in tagged_words:
    print(t)
# Out:
# ('TON', '.')
# ('618', 'NUM')
# ('(', '.')
# ('short', 'ADJ')
# ('for', 'ADP')
# ('Tonantzintla', 'NOUN')
# ('618', 'NUM')
# (')', '.')
# ('is', 'VERB')
# ('a', 'DET')
# ('hyperluminous', 'ADJ')
# (',', '.')
# ('broad-absorption-line', 'ADJ')
# (',', '.')
# ('radio-loud', 'ADJ')
# ('quasar', 'NOUN')
# ('and', 'CONJ')
# ('Lyman-alpha', 'NOUN')
# ('blob', 'NOUN')
# ('located', 'VERB')
# ('near', 'ADP')
# ('the', 'DET')
# ('border', 'NOUN')
# ('of', 'ADP')
# ('the', 'DET')
# ('constellations', 'NOUN')
# ('Canes', 'NOUN')
# ('Venatici', 'NOUN')
# ('and', 'CONJ')
# ('Coma', 'NOUN')
# ('Berenices', 'NOUN')
# (',', '.')
# ('with', 'ADP')
# ('the', 'DET')
# ('projected', 'VERB')
# ('comoving', 'NOUN')
# ('distance', 'NOUN')
# ('of', 'ADP')
# ('approximately', 'ADV')
# ('18.2', 'NUM')
# ('billion', 'NUM')
# ('light-years', 'NOUN')
# ('from', 'ADP')
# ('Earth', 'NOUN')
# ('.', '.')
